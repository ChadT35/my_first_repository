# %% [markdown]
# ***Chad Tsikalas (cpt268)
# Code Practice 3***

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = {"BRA": [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
           "JPN": [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
           "USA": [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
           "YEAR": [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)
weo
# Out:
#      BRA    JPN    USA  YEAR
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# 1a. The import statement loads Pandas into the python notebook so we can use its functionality.

# %% [markdown]
# 1b. dictionary

# %% [markdown]
# 1c. because we are using Pandas functionality to produce the dataframe and "pd" is the pseudonym we chose in the import statement

# %% [markdown]
# 1d. DataFrame (specifically, pandas.core.frame.DataFrame)

# %% [markdown]
# 1e. :

# %%
len(weo) # number of rows
# Out:
# 7

# %%
len(weo.columns.tolist()) # number of columns
# Out:
# 4

# %% [markdown]
# 1f:

# %%
print(weo.dtypes)
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# YEAR      int64
# dtype: object

# %% [markdown]
# If the columns hold numbers, it will return either a float or an int, depending on if the number has a decimal point. Otherwise, even if a string, all of the variables are objects.

# %% [markdown]
# 1g:

# %%
weo['YEAR']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: YEAR, dtype: int64

# %% [markdown]
# A series returning all of the years in a data format.

# %%
weo[["YEAR"]]
# Out:
#    YEAR
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %% [markdown]
# A dataframe returning all of the years in a dataframe format.

# %% [markdown]
# weo[[3]] returns an error, 3 is not an index

# %% [markdown]
# 1h:

# %%
weo["YEAR"].astype(float)
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: YEAR, dtype: float64

# %% [markdown]
# 1i:

# %%
t = weo.tail(3)
t
# Out:
#      BRA    JPN    USA  YEAR
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# t shows the "tail" or end of the data, in this case the last three rows. t is a DataFrame that shows only the final three rows.

# %% [markdown]
# 1j:

# %%
h = weo.head(4)
h
# Out:
#      BRA    JPN    USA  YEAR
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011

# %% [markdown]
# 1k: series

# %% [markdown]
# 1l:

# %%
weo["BRA/JPN"] = weo.BRA/weo.JPN
weo
# Out:
#      BRA    JPN    USA  YEAR   BRA/JPN
# 0  13.37  33.43  48.30  2008  0.399940
# 1  13.30  31.83  46.91  2009  0.417845
# 2  14.34  33.71  48.31  2010  0.425393
# 3  15.07  34.29  49.72  2011  0.439487
# 4  15.46  35.60  51.41  2012  0.434270
# 5  15.98  36.79  52.94  2013  0.434357
# 6  16.10  37.39  54.60  2014  0.430596

# %% [markdown]
# 1m

# %%
weo.drop("BRA/JPN", axis = 1)
# Out:
#      BRA    JPN    USA  YEAR
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# 1n:

# %%
weo.columns
# Out:
# Index(['BRA', 'JPN', 'USA', 'YEAR', 'BRA/JPN'], dtype='object')

# %%
weo.index #rows
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# 1o:

# %%
data = {"BRA": [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
           "JPN": [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
           "USA": [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
           "YEAR": [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)
weo
weo.set_index("YEAR")
# Out:
#         BRA    JPN    USA
# YEAR
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %% [markdown]
# 1p:

# %%
weo=weo.rename(columns = {"BRA" : "Brazil", "JPN" : "Japan", "USA" : "United States"})
weo
# Out:
#    Brazil  Japan  United States  YEAR
# 0   13.37  33.43          48.30  2008
# 1   13.30  31.83          46.91  2009
# 2   14.34  33.71          48.31  2010
# 3   15.07  34.29          49.72  2011
# 4   15.46  35.60          51.41  2012
# 5   15.98  36.79          52.94  2013
# 6   16.10  37.39          54.60  2014

# %% [markdown]
# 1q:

# %%
my_path = os.getcwd()
data_folder = my_path + "\data"
weo.to_excel(data_folder + "\weo_cp3.xlsx")

# %% [markdown]
# 1r:

# %%
weo = weo.set_index("YEAR")
countries = weo.columns.tolist()
weo[countries].mean()
# Out:
# Brazil           14.802857
# Japan            34.720000
# United States    50.312857
# dtype: float64

# %% [markdown]
# 1s:

# %%
weo.mean(axis = 1)
# Out:
# YEAR
# 2008    31.700000
# 2009    30.680000
# 2010    32.120000
# 2011    33.026667
# 2012    34.156667
# 2013    35.236667
# 2014    36.030000
# dtype: float64

# %% [markdown]
# 1t:

# %%
weo.plot()
plt.show()

# %% [markdown]
# 1u:

# %%
weo.plot(color = ["g","r","b"])
plt.show()

# %% [markdown]
# 1v:

# %%
weo.plot(logx = True)
plt.show()

# %% [markdown]
# 1w:

# %%
weo["Brazil"].plot()
plt.show()

# %% [markdown]
# 2:

# %%
url = 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv'
ep = pd.read_csv(url)

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# 2b: The file is the results to a survey, the variables are the questions asked and the responses are the values

# %% [markdown]
# 2c:

# %%
type(ep.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
print(ep.columns)
# Out:
# Index(['TimeStamp', 'Why have you enrolled in this course?  ', 'Program?',
#        'Programming Exp?', 'Statistics Experience?',
#        'What is your expected major or concentration? ',
#        'What career path most interests you? ',
#        'Do you use social media for information purposes?  Check all that apply.',
#        'What kinds of data most interest you?  List any that cross your mind.  ',
#        'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.'],
#       dtype='object')

# %% [markdown]
# 2d:

# %%
ep = ep.rename(columns = {'Why have you enrolled in this course?  ':"Why Enroll?", 
                          "What program are you enrolled in?": "Program?",
                          "How much programming experience have you had?": "Programming Experience?", 
                          "How much experience with probability and statistics have you had?": "Statistics Experience?", 
                          'What is your expected major or concentration? ': "Major/Concentration?", 
                          "What career path most interests you? ": "Career Path?", 
                          'Do you use social media for information purposes?  Check all that apply.': "Social media?", 
                          'What kinds of data most interest you?  List any that cross your mind.  ': "Interesting Data?", 
                          'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.': "Special Topcics?"})

# %%
ep
# Out:
#               TimeStamp                                        Why Enroll?  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# 2e:

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# To finish my major                                    1
# i am living in Santiago de Chile                      1
# I code/build websites in my spare time as a hobby     1
# I like a challenge                                    1
# Recommended by a professor.                           1
# Wanted to try something completely different          1
# Name: Why have you enrolled in this course?  , dtype: int64

# %% [markdown]
# First, the statement breaks ep into a list and chooses index 1 "[1]", which is the first question : "Why Enroll?". Then it calls the method "value_counts" which counts the frequency of each value in that column.

# %% [markdown]
# 3

# %%
url1 = "https://raw.githubusercontent.com/fivethirtyeight/data/master/"
url2 = "college-majors/recent-grads.csv"
url = url1 + url2

# %%
Data_538 = pd.read_csv(url)
df538 = pd.DataFrame(Data_538)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538.describe
# Out:
# <bound method NDFrame.describe of      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# ...

# %% [markdown]
# 173 rows x 21 columns

# %% [markdown]
# 3b:

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# 3c:

# %% [markdown]
# 2: Major Code, 4: Total number , 15,16,17: Median Salary, 25th Percentile, 75th Percentile. Represents a distributon of salaries for each major.

# %% [markdown]
# 3d:

# %%
df538 = df538.set_index("Major")

# %% [markdown]
# 3e:

# %%
df538 = df538.sort_values("Total",ascending = False)

# %% [markdown]
# 3f:

# %%
df538_top10 = df538.head(10)
df538_top10
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# NURSING                                   35        6107  209394.0   21773.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# POLITICAL SCIENCE AND GOVERNMENT          79        5506  182621.0   93880.0
#
#                                            Women               Major_category  \
# Major
# ...

# %% [markdown]
# 3g:

# %%
df538_top10['Median'].sort_values().plot(kind='barh')
plt.show()

# %%
df538_top10['P25th'].sort_values().plot(kind='barh')
plt.show()
